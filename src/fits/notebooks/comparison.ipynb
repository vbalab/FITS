# %%
import os

# root = Path(os.getcwd()).parent.parent
root = "/app/src"
os.chdir(root)

# %%
from fits.modelling.comparison import (
    CalculateParams,
    LoadBestModel,
    PlotComparisonModelGrid,
    ReadMetrics,
    VisualizeForecastSample,
)

# %%
NSAMPLE = 10

# %%
from fits.modelling.comparison import ReadAllMetrics

df = ReadAllMetrics()
print(df.to_string(float_format='{:.3f}'.format))
print('\nShape:', df.shape)
# Out:
# fd                       no_fd                                                               fd
# dataset            electricity      etth         exchange            weather        electricity        etth          exchange
# csdi                     0.065     0.217            0.013              0.107              0.074       0.262             0.012
# diffusion_ts             0.125     0.369            0.053              0.059              0.113       0.398             0.012
# falda                    0.089     0.373            0.088              0.088              0.111       4.652             0.428
# itransformer             0.086     0.268            0.014              0.070              0.108       0.269             0.014
# mrdiff                   0.131     0.332            0.031              0.123              0.178       0.411             0.014
# nsdiff                   0.121     0.318            0.044              0.410              0.340       0.672             0.222
# patchtst                 0.097     0.259            0.014              0.069              0.125       0.301             0.015
# sssd         6587110281431.579 63778.211 759644415245.474 20285022811621.051 20695873873165.473 6631062.737 1324317602438.737
# timegrad                 0.091     0.276            0.067              0.075              0.114       0.313             0.011
#
# Shape: (9, 7)
